# %%
import pandas as pd

# %%
booki = pd.read_csv('./bisbn.csv',encoding='latin-1')
bookg = pd.read_csv('./bgenre.csv',encoding='latin-1')

# %%
bookscs = booki.merge(bookg, on='title')

# %%
bookscs
# Out:
#              isbn                                              title  \
# 0       399135782                             The Kitchen God's Wife
# 1       440234743                                      The Testament
# 2       609804618  Our Dumb Century: The Onion Presents 100 Years...
# 3       345402871                                           Airframe
# 4       345417623                                           Timeline
# ...           ...                                                ...
# 26784  1561569119                                    Robinson Crusoe
# 26785   451521390                                         Pathfinder
# 26786  1902852036                                All the Queen's Men
# 26787   441011799                                    Singularity Sky
# 26788   395264707                                         Dreamsnake
#
#                       author  year           publisher  \
# 0                    Amy Tan  1991    Putnam Pub Group
# ...

# %%
bookscs.to_csv('combined.csv', index=False)

# %%
df1 = pd.read_csv('./Books.csv',encoding='latin-1')
df2 = pd.read_csv('./BBooks.csv',encoding='latin-1')
# Out:
# C:\Users\saroj\AppData\Local\Temp\ipykernel_8836\2132639372.py:1: DtypeWarning: Columns (7,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('./Books.csv',encoding='latin-1')

# %%
#merged_df = pd.merge(df1, df2, on= "Title", how="inner")
cbooks = df2.merge(df1, on='title')

# %%
cbooks
# Out:
#                        title                 series  \
# 0      To Kill a Mockingbird  To Kill a Mockingbird
# 1      To Kill a Mockingbird  To Kill a Mockingbird
# 2      To Kill a Mockingbird  To Kill a Mockingbird
# 3      To Kill a Mockingbird  To Kill a Mockingbird
# 4      To Kill a Mockingbird  To Kill a Mockingbird
# ...                      ...                    ...
# 26784                Charmed                    NaN
# 26785                Charmed                    NaN
# 26786         Vacuum Flowers                    NaN
# 26787         The Delta Star                    NaN
# 26788                Anasazi      Sense of Truth #2
#
#                                  author_x  rating  \
# 0                              Harper Lee    4.28
# 1                              Harper Lee    4.28
# 2                              Harper Lee    4.28
# 3                              Harper Lee    4.28
# 4                              Harper Lee    4.28
# ...

# %%
cbooks.to_csv('combined.csv', index=False)

# %%
ratings = pd.read_csv('./Ratings.csv',encoding='latin-1')

# %%
users = pd.read_csv('./Users.csv', encoding='latin-1')
# Out:
# C:\Users\saroj\AppData\Local\Temp\ipykernel_8836\2571707803.py:1: DtypeWarning: Columns (3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   users = pd.read_csv('./Users.csv', encoding='latin-1')

# %%
ratings
# Out:
#          user_id        isbn  rating
# 0         276725  034545104X       0
# 1         276726   155061224       5
# 2         276727   446520802       0
# 3         276729  052165615X       3
# 4         276729   521795028       6
# ...          ...         ...     ...
# 1048570   250764   451410777       0
# 1048571   250764   452264464       8
# 1048572   250764  048623715X       0
# 1048573   250764   486256588       0
# 1048574   250764   515069434       0
#
# [1048575 rows x 3 columns]

# %%
users
# Out:
#         user_id                                 location  age Unnamed: 3  \
# 0             1                  nyc, new york, usa;NULL  NaN        NaN
# 1             2                stockton, california, usa   18        NaN
# 2             3     moscow, yukon territory, russia;NULL  NaN        NaN
# 3             4                porto, v.n.gaia, portugal   17        NaN
# 4             5  farnborough, hants, united kingdom;NULL  NaN        NaN
# ...         ...                                      ...  ...        ...
# 278847   278854               portland, oregon, usa;NULL  NaN        NaN
# 278848   278855       tacoma, washington, united kingdom   50        NaN
# 278849   278856           brampton, ontario, canada;NULL  NaN        NaN
# 278850   278857           knoxville, tennessee, usa;NULL  NaN        NaN
# 278851   278858                dublin, n/a, ireland;NULL  NaN        NaN
#
#        Unnamed: 4  Unnamed: 5
# 0             NaN         NaN
# ...

# %%
cbooks
# Out:
#                        title                 series  \
# 0      To Kill a Mockingbird  To Kill a Mockingbird
# 1      To Kill a Mockingbird  To Kill a Mockingbird
# 2      To Kill a Mockingbird  To Kill a Mockingbird
# 3      To Kill a Mockingbird  To Kill a Mockingbird
# 4      To Kill a Mockingbird  To Kill a Mockingbird
# ...                      ...                    ...
# 26784                Charmed                    NaN
# 26785                Charmed                    NaN
# 26786         Vacuum Flowers                    NaN
# 26787         The Delta Star                    NaN
# 26788                Anasazi      Sense of Truth #2
#
#                                  author_x  rating  \
# 0                              Harper Lee    4.28
# 1                              Harper Lee    4.28
# 2                              Harper Lee    4.28
# 3                              Harper Lee    4.28
# 4                              Harper Lee    4.28
# ...

# %%
ratings_with_books = ratings.merge(cbooks, on='isbn')

# %%
ratings_with_books
# Out:
#         user_id        isbn  rating_x                           title  \
# 0        276726   155061224         5                Rites of Passage
# 1        276726   155061224         5                Rites of Passage
# 2        276727   446520802         0                    The Notebook
# 3        276744  038550120X         7                 A Painted House
# 4        276746   425115801         0                       Lightning
# ...         ...         ...       ...                             ...
# 261263   250764   451191692         0                  Remote Control
# 261264   250764   451192001         0  How Stella Got Her Groove Back
# 261265   250764   451193911         0                    Atlanta Heat
# 261266   250764   451400763         0                           Quest
# 261267   250764   451401387         0              The Road to Avalon
#
#                              series  \
# 0       To the Ends of the Earth #1
# 1                               NaN
# ...

# %%
number_rating = ratings_with_books.groupby('title')['rating_x'].count().reset_index()

# %%
number_rating
# Out:
#                                                   title  rating_x
# 0                                          'Salem's Lot        80
# 1                             ...And Ladies of the Club         5
# 2                    1,000 Places to See Before You Die        16
# 3                10 Secrets for Success and Inner Peace         5
# 4                                    100 Selected Poems         3
# ...                                                 ...       ...
# 9444                                             Zombie        16
# 9445                                       Zombie Lover         1
# 9446                                    Zorba the Greek         3
# 9447  Zoya's Story: An Afghan Woman's Struggle for F...        11
# 9448                            god bless the gargoyles         1
#
# [9449 rows x 2 columns]

# %%
final_rating = ratings_with_books.merge(number_rating, on='title')

# %%
number_rating
# Out:
#                                                   title  rating_x
# 0                                          'Salem's Lot        80
# 1                             ...And Ladies of the Club         5
# 2                    1,000 Places to See Before You Die        16
# 3                10 Secrets for Success and Inner Peace         5
# 4                                    100 Selected Poems         3
# ...                                                 ...       ...
# 9444                                             Zombie        16
# 9445                                       Zombie Lover         1
# 9446                                    Zorba the Greek         3
# 9447  Zoya's Story: An Afghan Woman's Struggle for F...        11
# 9448                            god bless the gargoyles         1
#
# [9449 rows x 2 columns]

# %%
final_rating
# Out:
#         user_id        isbn  rating_x_x                           title  \
# 0        276726   155061224           5                Rites of Passage
# 1        276726   155061224           5                Rites of Passage
# 2        276727   446520802           0                    The Notebook
# 3        276744  038550120X           7                 A Painted House
# 4        276746   425115801           0                       Lightning
# ...         ...         ...         ...                             ...
# 261263   250764   451191692           0                  Remote Control
# 261264   250764   451192001           0  How Stella Got Her Groove Back
# 261265   250764   451193911           0                    Atlanta Heat
# 261266   250764   451400763           0                           Quest
# 261267   250764   451401387           0              The Road to Avalon
#
#                              series  \
# 0       To the Ends of the Earth #1
# ...

# %%
final_rating.drop_duplicates(['user_id','title'],inplace=True)

# %%
final_rating
# Out:
#         user_id        isbn  rating_x_x                           title  \
# 0        276726   155061224           5                Rites of Passage
# 2        276727   446520802           0                    The Notebook
# 3        276744  038550120X           7                 A Painted House
# 4        276746   425115801           0                       Lightning
# 6        276746  055356451X           0                      Night Sins
# ...         ...         ...         ...                             ...
# 261262   250764   451191013           0                  The Regulators
# 261264   250764   451192001           0  How Stella Got Her Groove Back
# 261265   250764   451193911           0                    Atlanta Heat
# 261266   250764   451400763           0                           Quest
# 261267   250764   451401387           0              The Road to Avalon
#
#                              series  \
# 0       To the Ends of the Earth #1
# ...

# %%
book_pivot = final_rating.pivot_table(columns='user_id', index='title', values= 'rating_x')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 book_pivot = final_rating.pivot_table(columns='user_id', index='title', values= 'rating_x')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:9482, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9465 @Substitution("")
#    9466 @Appender(_shared_docs["pivot_table"])
#    9467 def pivot_table(
#    (...)
#    9478     sort: bool = True,
#    9479 ) -> DataFrame:
#    9480     from pandas.core.reshape.pivot import pivot_table
# -> 9482     return pivot_table(
#    9483         self,
#    9484         values=values,
#    9485         index=index,
#    9486         columns=columns,
#    9487         aggfunc=aggfunc,
# ...
